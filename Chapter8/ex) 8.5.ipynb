# %% [markdown]
# # 1. 문제정의
# Prim의 최소비용 신장트리 알고리즘을 구현하라.

# %% [markdown]
# # 2. 알고리즘 설명
# 1. 그래프에서 시작 정점을 선택하여 초기 트리를 만든다.
# 2. 현재 트리의 정점들과 인접한 정점들 중에서 간선의 가중치가 가장 작은 정점 v를 선택
# 3. 이 정점 v와 이때의 간선을 트리에 추가
# 4. 모든 정점이 삽입될 때 까지 2번으로 이동

# %% [markdown]
# # 3. 손으로 푼 예제
# ![hand_image.png](attachment:hand_image.png)

# %% [markdown]
# # 4. 코드 설명
# #### 1. 자료구조 정의
# vertex: 정점
# weight: 간선의 가중치 (INF(9999)는 갈수 없을경우)
#
# #### 2. 함수 정의
# ##### getMinVertex(dist, selected):
#
#
# ##### MSTPrim(vertex, adj):

# %% [markdown]
# # 5. 알고리즘 코드
# 입력 가중치 그래프:
# ![7.10.pic.png](attachment:7.10.pic.png)

# %%
INF = 999

def getMinVertex(dist, selected):
    minv = -1
    mindist = INF

    for v in range(len(dist)):
        if not selected[v] and dist[v] < mindist:
            mindist = dist[v]
            minv = v
    return minv

def MSTPrim(vertex, adj):
    vsize = len(vertex)
    dist = [INF] * vsize
    dist[0] = 0
    selected = [False] * vsize

    for i in range(vsize):
        u = getMinVertex(dist, selected)
        selected[u] = True
        print(vertex[u], end=':')
        print(dist)

        for v in range(vsize):
            if(adj[u][v] != None):
                if selected[v]==False and adj[u][v] < dist[v]:
                    dist[v] = adj[u][v]
                
vertex = ['A', 'B', 'C', 'D', 'E', 'F' ,'G']
weight = [[None, 29, None, None, None, 10, None,],
          [29, None, 16, None, None, None, 15,],
          [None, 16, None, 12, None, None, None,],
          [None, None, 12, None, 22, None, 18,],
          [None, None, None, 22, None, 27, 25,],
          [10, None, None, None, 27, None, None,],
          [None, 15, None, 18, 25, None, None,],]
print("MST By Prim's Algorithm")
MSTPrim(vertex, weight)
# Out:
# MST By Prim's Algorithm
# A:[0, 999, 999, 999, 999, 999, 999]
# F:[0, 29, 999, 999, 999, 10, 999]
# E:[0, 29, 999, 999, 27, 10, 999]
# D:[0, 29, 999, 22, 27, 10, 25]
# C:[0, 29, 12, 22, 27, 10, 18]
# B:[0, 16, 12, 22, 27, 10, 18]
# G:[0, 16, 12, 22, 27, 10, 15]

# %% [markdown]
# # 6. 테스트 코드 (입력을 바꾸어)
# 입력 가중치 그래프:
# ![7.10.pic2.png](attachment:7.10.pic2.png)

# %%
INF = 999

def getMinVertex(dist, selected):
    minv = -1
    mindist = INF

    for v in range(len(dist)):
        if not selected[v] and dist[v] < mindist:
            mindist = dist[v]
            minv = v
    return minv

def MSTPrim(vertex, adj):
    vsize = len(vertex)
    dist = [INF] * vsize
    dist[0] = 0
    selected = [False] * vsize

    for i in range(vsize):
        u = getMinVertex(dist, selected)
        selected[u] = True
        print(vertex[u], end=':')
        print(dist)

        for v in range(vsize):
            if(adj[u][v] != None):
                if selected[v]==False and adj[u][v] < dist[v]:
                    dist[v] = adj[u][v]
                
vertex = ['A', 'B', 'C', 'D', 'E', 'F' ,'G']
weight = [[None, 29, None, None, None, 10, None,],
          [29, None, 16, None, None, None, 15,],
          [None, 16, None, 12, None, None, None,],
          [None, None, 12, None, 22, None, 18,],
          [None, None, None, 22, None, 27, 25,],
          [10, None, None, None, 27, None, None,],
          [None, 15, None, 18, 25, None, None,],]
print("MST By Prim's Algorithm")
MSTPrim(vertex, weight)
# Out:
# Shortest Path By Floyd's Algorithm
# =======================
#    0    4   14    3  INF
#    4    0   18    7    5
#   14   18    0   17    1
#    3    7   17    0    2
#  INF    5    1    2    0
# =======================
#    0    4   14    3    9
#    4    0   18    7    5
#   14   18    0   17    1
#    3    7   17    0    2
#    9    5    1    2    0
# =======================
#    0    4   14    3    9
#    4    0   18    7    5
#   14   18    0   17    1
#    3    7   17    0    2
#    9    5    1    2    0
# =======================
#    0    4   14    3    5
#    4    0   18    7    5
#   14   18    0   17    1
#    3    7   17    0    2
#    5    5    1    2    0
# =======================
#    0    4    6    3    5
#    4    0    6    7    5
#    6    6    0    3    1
#    3    7    3    0    2
#    5    5    1    2    0

# %% [markdown]
# # 7. 수행 결과

# %% [markdown]
# ![7.10.output.png](attachment:7.10.output.png)

# %% [markdown]
# # 8. 복잡도 분석
# ### 시간 복잡도:
# shortest_path_floyd()의 함수에 3중 for문이 있다.
# for k in range(vsize):
#         for i in range(vsize):
#             for j in range(vsize):
# vsize는 정점의 개수이므로 정점의 개수가 n이라고 했을때 각 루프는 최대 n번 반복된다.
# 그러므로 시간복잡도는 O(n^3) 이다.
